# %%
import numpy as np
import scipy as sp 
import matplotlib.pyplot as ply

# %%
A = np.ndarray([
    [0.304, 0, -1, 0.026, 0],
    [-18.3, -1.24, -0.395, 0, 0],
    [4.97, -0.05, -0.238, 0 ,0],
    [0, 1, 0, 0, 0],
    [0, 0, 1, 0, 0]
])

B = [
    [-0.0007],
    [1.95],
    [0.2],
    [0],
    [0]
]

C= [1, 1, 1, 1, 1]

D = [0]
